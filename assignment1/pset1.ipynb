# %% [markdown]
# # **0. Load Preliminary Functions**

# %% [markdown]
# # a. Import Libraries and Functions

# %%
import torch
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # b. MNIST Data Loader

# %%
tensor_transform = transforms.ToTensor()

batch_size = 256
MNIST_dataset = datasets.MNIST(root = "./data",
									train = True,
									download = True,
									transform = tensor_transform)

MNIST_loader = torch.utils.data.DataLoader(dataset = MNIST_dataset,
							   batch_size = batch_size,
								 shuffle = True)

# %% [markdown]
# # c. Training Function

# %%
from math import e
mse = torch.nn.MSELoss()

def loss_func(model, x, reg_func=None, coeff=1e-3):
    output = model(x)
    err = mse(output['imgs'], x)
    logpx_z = -1.0 * torch.sum(err)

    if reg_func is not None:
      reg = reg_func(output)
    else:
      reg = 0.0

    return -1.0 * torch.mean(logpx_z + coeff * reg)

def train(dataloader, model, loss_func, optimizer, epochs):
    losses = []
#加载进度条
    for epoch in tqdm(range(epochs), desc='Epochs'):
        running_loss = 0.0
        batch_progress = tqdm(dataloader, desc='Batches', leave=False)
#enumerate额外返回序号
        for iter, (images, labels) in enumerate(batch_progress):
            batch_size = images.shape[0]
            images = images.reshape(batch_size, -1).to(device)
            loss = loss_func(model, images)
#更新
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            avg_loss = running_loss / len(MNIST_dataset) * batch_size
            losses.append(loss.item())

        tqdm.write(f'----\nEpoch [{epoch+1}/{epochs}], Average Loss: {avg_loss:.4f}\n')

    return losses

# %% [markdown]
# # d. Evaluation Function

# %%
def plot_latent_images(model, n, digit_size=28):
    grid_x = np.linspace(-2, 2, n)
    grid_y = np.linspace(-2, 2, n)

    image_width = digit_size * n
    image_height = digit_size * n
    image = np.zeros((image_height, image_width))

    for i, yi in enumerate(grid_x):
        for j, xi in enumerate(grid_y):
            z = torch.tensor([[xi, yi]], dtype=torch.float32).to(device)
            with torch.no_grad():
                x_decoded = model.decode(z)
            digit = x_decoded.view(digit_size, digit_size).cpu().numpy()
            image[i * digit_size: (i + 1) * digit_size,
                  j * digit_size: (j + 1) * digit_size] = digit

    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap='Greys_r')
    plt.axis('Off')
    plt.show()


def eval(model):
    original_imgs = torch.cat([MNIST_dataset[i][0] for i in range(5)])
    with torch.no_grad():
      res = model(original_imgs.reshape(5, -1).to(device))
      reconstructed_imgs = res['imgs']
      reconstructed_imgs = reconstructed_imgs.cpu().reshape(*original_imgs.shape)

    fig, axes = plt.subplots(5, 2, figsize=(10, 25))

    for i in range(5):
        original_image = original_imgs[i].reshape(28, 28)
        axes[i, 0].imshow(original_image, cmap='gray')
        axes[i, 0].set_title(f'Original Image {i+1}')
        axes[i, 0].axis('off')

        reconstructed_image = reconstructed_imgs[i].reshape(28, 28)
        axes[i, 1].imshow(reconstructed_image, cmap='gray')
        axes[i, 1].set_title(f'Reconstructed Image {i+1}')
        axes[i, 1].axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **1. AutoEncoder (AE)**

# %% [markdown]
# ## a. Model

# %%
class AE(torch.nn.Module):
    def __init__(self, input_dim, hidden_dims):
        super().__init__()

        assert hidden_dims[-1] == 2, "always use 2 as the latent dimension for generating a 2D image grid during evaluation"
        
        ##################
        ### Problem 1 (a): finish the implementation for encoder and decoder
        ##################
        
        # --- 1. 构建 Encoder ---
        encoder_layers = [] 
        in_dim = input_dim 
        # 只要不是最后一层（最后一层是2维潜空间，不需要激活），就加一个激活函数 ReLU 
        for out_dim in hidden_dims:
            encoder_layers.append(torch.nn.Linear(in_dim, out_dim))
            if out_dim != hidden_dims[-1]: 
                encoder_layers.append(torch.nn.ReLU())
            in_dim = out_dim 
            
        self.encoder = torch.nn.Sequential(*encoder_layers)
        
        # --- 2. 构建 Decoder ---
        decoder_layers = []
        in_dim = hidden_dims[-1]
        for out_dim in reversed(hidden_dims[:-1]):
            decoder_layers.append(torch.nn.Linear(in_dim, out_dim))
            decoder_layers.append(torch.nn.ReLU())
            in_dim = out_dim
        decoder_layers.append(torch.nn.Linear(in_dim, input_dim))
        decoder_layers.append(torch.nn.Sigmoid()) # Sigmoid 压平像素值
        self.decoder = torch.nn.Sequential(*decoder_layers)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decode(encoded)
        return {"imgs": decoded}

### Test
hidden_dims = [128, 64, 36, 18, 2]
input_dim = 256
test_tensor = torch.randn([1, input_dim]).to(device)

ae_test = AE(input_dim, hidden_dims).to(device)

with torch.no_grad():
  test_out = ae_test(test_tensor)

# %% [markdown]
# ## b. Loss Functions and Optimizers

# %%
def loss_AE(model, x):
    reconstructed = model(x)['imgs']
    return mse(reconstructed, x)

image_shape = MNIST_dataset[0][0].shape
input_dim = torch.prod(torch.tensor(image_shape)).item()
print("input_dim: ", input_dim)

hidden_dims = [128, 32, 16, 2]

ae = AE(input_dim, hidden_dims).to(device)
print(ae)

optimizer_ae = torch.optim.Adam(ae.parameters(),
                                lr = 1e-3,
                                weight_decay = 1e-8)
# Out:
# input_dim:  784
# AE(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=784, bias=True)
#     (7): Sigmoid()
#   )
# )

# %% [markdown]
# ## c. Training

# %%
##################
### Problem 1 (b): Train AE
epochs = 20

log_ae = train(MNIST_loader, ae, loss_AE, optimizer_ae, epochs)
##################
# Out:
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [1/20], Average Loss: 0.0313
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [2/20], Average Loss: 0.0215
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [3/20], Average Loss: 0.0203
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [4/20], Average Loss: 0.0194
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [5/20], Average Loss: 0.0189
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [6/20], Average Loss: 0.0185
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [7/20], Average Loss: 0.0181
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [8/20], Average Loss: 0.0177
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [9/20], Average Loss: 0.0174
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [10/20], Average Loss: 0.0171
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [11/20], Average Loss: 0.0169
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [12/20], Average Loss: 0.0167
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [13/20], Average Loss: 0.0165
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [14/20], Average Loss: 0.0163
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [15/20], Average Loss: 0.0162
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [16/20], Average Loss: 0.0161
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [17/20], Average Loss: 0.0159
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [18/20], Average Loss: 0.0158
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [19/20], Average Loss: 0.0157
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [20/20], Average Loss: 0.0156

# %% [markdown]
# ## d. Evaluation

# %%
##################
### Problem 1 (b): Evaluate AE
eval(ae)
plot_latent_images(ae, n=8)
##################

# %% [markdown]
# # **2. Variational  AutoEncoder (VAE)**
# ## a. Model

# %%
class VAE(torch.nn.Module):
  def __init__(self, input_dim, hidden_dims, decode_dim=-1, use_sigmoid=True):
      '''
      input_dim: The dimensionality of the input data.
      hidden_dims: A list of hidden dimensions for the layers of the encoder and decoder.
      decode_dim: (Optional) Specifies the dimensions to decode, if different from input_dim.
      '''
      super().__init__()

      self.z_size = hidden_dims[-1] // 2

      ##################
      ### Problem 2(b): finish the implementation for encoder and decoder
      ##################
      
      # --- 1. 构建 Encoder ---
      encoder_layers = []
      in_dim = input_dim
      # 遍历 hidden_dims，直到最后一层之前都加 ReLU
      for i, out_dim in enumerate(hidden_dims):
          encoder_layers.append(torch.nn.Linear(in_dim, out_dim))
          # 判断是不是最后一层，用索引来判断比用值更安全（防止中间刚好有出现相同的维度）
          if i < len(hidden_dims) - 1:
              encoder_layers.append(torch.nn.ReLU())
          in_dim = out_dim
          
      self.encoder = torch.nn.Sequential(*encoder_layers)
      
      # --- 2. 构建 Decoder ---
      decoder_layers = []
      in_dim = self.z_size
      for out_dim in reversed(hidden_dims[:-1]):
          decoder_layers.append(torch.nn.Linear(in_dim, out_dim))
          decoder_layers.append(torch.nn.ReLU())
          in_dim = out_dim
          
      # 运用三元表达式来决定最后一层的输出维度
      final_out_dim = input_dim if decode_dim == -1 else decode_dim
      decoder_layers.append(torch.nn.Linear(in_dim, final_out_dim))
      
      if use_sigmoid:
          decoder_layers.append(torch.nn.Sigmoid()) # Sigmoid 压平像素值

      self.decoder = torch.nn.Sequential(*decoder_layers)

  def encode(self, x):
      mean, logvar = torch.split(self.encoder(x), split_size_or_sections=[self.z_size, self.z_size], dim=-1)
      return mean, logvar

  def reparameterize(self, mean, logvar, n_samples_per_z=1):
      ##################
      ### Problem 2(c): finish the implementation for reparameterization
      ##################
      std=torch.exp(0.5 * logvar)
      eps = torch.randn_like(std) 
      z=eps * std + mean 
      return z

  def decode(self, z):
      probs = self.decoder(z)
      return probs

  def forward(self, x, n_samples_per_z=1):
      mean, logvar = self.encode(x)

      batch_size, latent_dim = mean.shape
      if n_samples_per_z > 1:
        mean = mean.unsqueeze(1).expand(batch_size, n_samples_per_z, latent_dim)
        logvar = logvar.unsqueeze(1).expand(batch_size, n_samples_per_z, latent_dim)

        mean = mean.contiguous().view(batch_size * n_samples_per_z, latent_dim)
        logvar = logvar.contiguous().view(batch_size * n_samples_per_z, latent_dim)

      z = self.reparameterize(mean, logvar, n_samples_per_z)
      x_probs = self.decode(z)

      x_probs = x_probs.reshape(batch_size, n_samples_per_z, -1)
      x_probs = torch.mean(x_probs, dim=[1])

      return {
          "imgs": x_probs,
          "z": z,
          "mean": mean,
          "logvar": logvar
      }

### Test
hidden_dims = [128, 64, 36, 18, 18]
input_dim = 256
test_tensor = torch.randn([1, input_dim]).to(device)

vae_test = VAE(input_dim, hidden_dims).to(device)

with torch.no_grad():
  test_out = vae_test(test_tensor)

# %% [markdown]
# ## b. Loss Functions
#
# ### Loss 1: Stoachastic Gradient Variational Bayes (SGVB) Estimator
#
# VAEs are trained by maximizing the Evidence Lower Bound (ELBO) on the marginal log-likelihood:
# $$\log p(x) \geq \mathbb{E}_{q(z|x)}[\log\frac{p(x, z)}{q(z|x)}] = \mathrm{ELBO},$$
#
# where $x$ is the data (binary images for MNIST) and $z$ is the latent code.
#
# In practice, the above expectation is estimated using Monte Carlo sampling, yielding the generic Stoachastic Gradient Variational Bayes (SGVB) estimator,
# $$\mathrm{ELBO} \approx \sum_{i, j} [\log p(x_i|z_{i, j}) + \log p(z_{i, j}) - \log q(z_{i, j}|x_i)], $$
# where $z_{i, j}$ is sampled from $ q(z|x_i) = \mathcal{N}(z;\mu_i, \sigma^2_i \mathbf{I})$. In this assignment, we only sample one $z_{i,j}$ for each $x_i$ (see the function ``reparameterize()`` in the ``VAE()`` class).

# %%
##### Loss 1: SGVB #####
log2pi = torch.log(2.0 * torch.tensor(np.pi)).to(device)
torch_zero = torch.tensor(0.0).to(device)

def log_normal_pdf(sample, mean, logvar, raxis=1):
    ##################
    ### Problem 2(d): finish the implementation for the log-probability for normal distribution with mean and var
    ##################
    # 公式: -0.5 * (log(2*pi) + log(sigma^2) + (x - mu)^2 / sigma^2)
    # 在这里: x 是 sample, mu 是 mean, log(sigma^2) 是 logvar, sigma^2 是 exp(logvar)
    log_p = -0.5 * (log2pi + logvar + ((sample - mean) ** 2) / torch.exp(logvar))
    
    # 沿着指定的维度(通常是特征维度)求和,联合概率
    return torch.sum(log_p, dim=raxis)

def loss_SGVB(output):
    logpz = log_normal_pdf(output['z'], torch_zero, torch_zero)
    logqz_x = log_normal_pdf(output['z'], output['mean'], output['logvar'])
    return logpz -logqz_x

# %% [markdown]
# ### Loss 2: KL Divergence w/o Estimation
# In many cases, Monte Carlo sampling is not necessary to estimate all the terms of ELBO, as some terms can be integrated analytically. In the assignment, you derived the cases where the ELBO can be expressed as an analytical KL-divergence plus the expected reconstruction error, specifically when both $q(z|x)$ and $p(z)$ are Gaussian distributions:
# $$\mathrm{ELBO} ≈ -D_{KL}(q(z|x) || p(z)) + \sum_{i, j} \log p(x_i|z_{i, j}) = \\\frac{1}{2}\sum_{d}(1+\log((\sigma_d)^2) - (\mu_d)^2 - (\sigma_d)^2) + \sum_{i, j} \log p(x_i|z_{i, j})$$

# %%
##### Loss 2: KL w/o Estimation #####
def loss_KL_wo_E(output):
    var = torch.exp(output['logvar'])
    logvar = output['logvar']
    mean = output['mean']

    return -0.5 * torch.sum(torch.pow(mean, 2)
                            + var - 1.0 - logvar,
                            dim=[1])

# %% [markdown]
# ## c. Verifying loss 1 == loss 2

# %%
##################
### Problem 3(b): Check if the analytical KL divergence matches the Monte Carlo estimate.
hidden_dims = [128, 32, 16, 4]
image_shape = MNIST_dataset[0][0].shape
input_dim = torch.prod(torch.tensor(image_shape)).item()
vae_test = VAE(input_dim, hidden_dims).to(device)

all_l_sgvb, all_KL_wo_E = [], []
all_n_samples_per_z = list(range(1, 4000, 100))

with torch.no_grad():
    for n_samples_per_z in all_n_samples_per_z:
        for _, (imgs, _) in enumerate(MNIST_loader):
            
            # --- FIX: 取一小部分图片(比如16张)用来测试即可，防止计算大量样本时撑爆内存 (OOM) ---
            imgs = imgs[:16]
            
            batch_size = imgs.shape[0]
            imgs = imgs.reshape(batch_size, -1).to(device)

            output = vae_test(imgs, n_samples_per_z=n_samples_per_z)

            l_sgvb = torch.mean(loss_SGVB(output))
            l_KL_wo_E = torch.mean(loss_KL_wo_E(output))

            all_l_sgvb.append(l_sgvb.item())
            all_KL_wo_E.append(l_KL_wo_E.item())
            break

# Plot the two curves
plt.figure(figsize=(12, 6))

plt.plot(all_n_samples_per_z, all_l_sgvb, label='SGVB Loss')
plt.plot(all_n_samples_per_z, all_KL_wo_E, label='KL Divergence (w/o E)')

plt.xlabel('Number of Samples per z')
plt.ylabel('Loss')
plt.legend()

plt.grid(True)
plt.show()
##################

# %%
import torch
print(device)
print(torch.cuda.is_available())
# Out:
# cuda
# True

# %% [markdown]
# ## d. Training with ELBO loss

# %%
##################
### Problem 3(c): Train VAE with ELBO loss
epochs = 20

hidden_dims = [128, 32, 16, 4]
assert hidden_dims[-1] == 4, "always use 4 as the latent dimension for generating a 2D image grid during evaluation"

image_shape = MNIST_dataset[0][0].shape
input_dim = torch.prod(torch.tensor(image_shape)).item()
print("input_dim: ", input_dim)

vae_sgvb = VAE(input_dim, hidden_dims).to(device)
print(vae_sgvb)

coeff = 1e-3

optimizer_vae_sgvb = torch.optim.Adam(vae_sgvb.parameters(),
                                lr = 1e-4,
                                weight_decay = 1e-8)

log_vae_sgvb = train(MNIST_loader, vae_sgvb, lambda model, x: loss_func(model, x, reg_func=loss_SGVB, coeff=1e-3), optimizer_vae_sgvb, epochs)
##################
# Out:
# input_dim:  784
# VAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=4, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=784, bias=True)
#     (7): Sigmoid()
#   )
# )
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [1/20], Average Loss: 0.0623
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [2/20], Average Loss: 0.0297
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [3/20], Average Loss: 0.0270
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [4/20], Average Loss: 0.0258
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [5/20], Average Loss: 0.0251
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [6/20], Average Loss: 0.0246
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [7/20], Average Loss: 0.0242
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [8/20], Average Loss: 0.0238
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [9/20], Average Loss: 0.0235
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [10/20], Average Loss: 0.0234
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [11/20], Average Loss: 0.0232
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [12/20], Average Loss: 0.0231
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [13/20], Average Loss: 0.0230
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [14/20], Average Loss: 0.0228
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [15/20], Average Loss: 0.0227
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [16/20], Average Loss: 0.0224
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [17/20], Average Loss: 0.0220
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [18/20], Average Loss: 0.0218
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [19/20], Average Loss: 0.0217
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [20/20], Average Loss: 0.0216

# %% [markdown]
# ## e. Evaluation

# %%
##################
### Problem 3(c): Evaluate VAE with ELBO loss
eval(vae_sgvb)
plot_latent_images(vae_sgvb, n=8)
##################

# %% [markdown]
# ## f. Training with KL Divergence w/o Estimation

# %%
##################
### Problem 3(c): Train VAE with analytical KL
epochs = 20

hidden_dims = [128, 32, 16, 4]
assert hidden_dims[-1] == 4, "always use 4 as the latent dimension for generating a 2D image grid during evaluation"

image_shape = MNIST_dataset[0][0].shape
input_dim = torch.prod(torch.tensor(image_shape)).item()
print("input_dim: ", input_dim)

vae_kl_wo_e = VAE(input_dim, hidden_dims).to(device)
print(vae_kl_wo_e)

optimizer_vae_kl_wo_e = torch.optim.Adam(vae_kl_wo_e.parameters(),
                                lr = 1e-4,
                                weight_decay = 1e-8)

log_vae_kl_wo_e = train(MNIST_loader, vae_kl_wo_e, lambda model, x: loss_func(model, x, reg_func=loss_KL_wo_E, coeff=1e-3), optimizer_vae_kl_wo_e, epochs)
##################
# Out:
# input_dim:  784
# VAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=4, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=784, bias=True)
#     (7): Sigmoid()
#   )
# )
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [1/20], Average Loss: 0.0635
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [2/20], Average Loss: 0.0292
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [3/20], Average Loss: 0.0262
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [4/20], Average Loss: 0.0252
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [5/20], Average Loss: 0.0246
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [6/20], Average Loss: 0.0241
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [7/20], Average Loss: 0.0237
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [8/20], Average Loss: 0.0235
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [9/20], Average Loss: 0.0233
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [10/20], Average Loss: 0.0231
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [11/20], Average Loss: 0.0229
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [12/20], Average Loss: 0.0228
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [13/20], Average Loss: 0.0224
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [14/20], Average Loss: 0.0221
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [15/20], Average Loss: 0.0218
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [16/20], Average Loss: 0.0217
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [17/20], Average Loss: 0.0216
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [18/20], Average Loss: 0.0215
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [19/20], Average Loss: 0.0214
# Batches:   0%|          | 0/235 [00:00<?, ?it/s]
# ----
# Epoch [20/20], Average Loss: 0.0213

# %% [markdown]
# ## g. Evaluation

# %%
##################
### Problem 3(c): Evaluate VAE with analytical KL
eval(vae_kl_wo_e)
plot_latent_images(vae_kl_wo_e, n=8)
##################

# %% [markdown]
# # **3. Torus**
#
# ## a. Data Generation

# %%
def generate_torus_point_cloud(R, r, num_points=1000, seed=1234):
    """
    Parameters:
    - R: Major radius of the torus (distance from the center of the tube to the center of the torus).
    - r: Minor radius of the torus (radius of the tube).
    - num_points: Number of points to sample in the point cloud.

    Returns:
    - x, y, z: Arrays containing the x, y, and z coordinates of the sampled points.
    """
    np.random.seed(seed)
    u = np.random.uniform(0, 2 * np.pi, num_points)
    np.random.seed(seed+1)
    v = np.random.uniform(0, 2 * np.pi, num_points)

    x = (R + r * np.cos(v)) * np.cos(u)
    y = (R + r * np.cos(v)) * np.sin(u)
    z = r * np.sin(v)

    points = np.vstack((x, y, z)).T

    return points

def plot_torus_point_cloud(x, y, z, ax, color='b', name='Training Data'):
    """
    Plots the 3D point cloud of a torus.
    """
    ax.scatter(x, y, z, c=color, marker='o', s=5)

    # Set equal scaling for all axes
    max_range = np.array([x.max()-x.min(), y.max()-y.min(), z.max()-z.min()]).max() / 2.0

    mid_x = (x.max() + x.min()) * 0.5
    mid_y = (y.max() + y.min()) * 0.5
    mid_z = (z.max() + z.min()) * 0.5

    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(name)
    return ax

class TorusPointCloudDataset(torch.utils.data.Dataset):
    def __init__(self, R, r, num_points=1000):
        """
        Args:
            R (float): Major radius of the torus.
            r (float): Minor radius of the torus.
            num_points (int): Number of points to generate.
        """
        points = generate_torus_point_cloud(R, r, num_points)
        self.points = torch.tensor(points, dtype=torch.float32)

    def __len__(self):
        return len(self.points)

    def __getitem__(self, idx):
        return self.points[idx], 0 # dummy label

R = 1.0
r = 0.5
num_points = 3000

torus_pc_dataset = TorusPointCloudDataset(R, r, num_points)
torus_pc_dataloader = torch.utils.data.DataLoader(torus_pc_dataset, batch_size=3000, shuffle=True)


fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
plot_torus_point_cloud(torus_pc_dataset.points[:, 0], torus_pc_dataset.points[:, 1], torus_pc_dataset.points[:, 2], ax)
plt.show()

# %% [markdown]
# ## b. Network Architecture

# %%
class PositionalEncoding3D(torch.nn.Module):
    def __init__(self, num_frequencies=10):
        """
        Initializes the positional encoding for 3D coordinates.

        Args:
            num_frequencies (int): The number of different frequencies to use for encoding.
        """
        super().__init__()
        self.num_frequencies = num_frequencies
        self.frequencies = 2 ** torch.arange(num_frequencies, dtype=torch.float32)

    def forward(self, points):
        """
        Applies positional encoding to the 3D points.

        Args:
            points (torch.Tensor): N x 3 tensor of 3D coordinates.

        Returns:
            torch.Tensor: N x (6*num_frequencies) tensor of encoded coordinates.
        """
        encoded_points = []
        for i in range(points.shape[1]):  # For each dimension (x, y, z)
            for freq in self.frequencies:
                encoded_points.append(torch.sin(freq * points[:, i:i+1]))
                encoded_points.append(torch.cos(freq * points[:, i:i+1]))
        return torch.cat(encoded_points, dim=-1)

###############
### Problem 4(c): Create your own VAE
###############

class PointVAE(torch.nn.Module):
    def __init__(self, hidden_dims):
        super().__init__()

        self.pos_enc = PositionalEncoding3D()
        #############
        ### Problem 4(c): Create your own VAE
        self.vae = VAE(input_dim=self.pos_enc.num_frequencies * 6, hidden_dims=hidden_dims, decode_dim=3, use_sigmoid=False)
        #############

    def forward(self, x):
        emb = self.pos_enc(x)
        return self.vae(emb)

# %% [markdown]
# ## c. Training

# %%
#############
### Problem 4(a): Train VAE on torus data
epochs = 1000

hidden_dims = [32, 16, 8] # -> 2/3 dim

point_vae = PointVAE(hidden_dims).to(device)
print(point_vae)

optimizer_point_vae = torch.optim.Adam(point_vae.parameters(),
                                lr = 1e-3,
                                weight_decay = 1e-8)

log_point_vae = train(torus_pc_dataloader, point_vae, lambda model, x: loss_func(model, x, reg_func=loss_KL_wo_E, coeff=0.0), optimizer_point_vae, epochs)
#############
# Out:
# PointVAE(
#   (pos_enc): PositionalEncoding3D()
#   (vae): VAE(
#     (encoder): Sequential(
#       (0): Linear(in_features=60, out_features=32, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=32, out_features=16, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=16, out_features=8, bias=True)
#     )
#     (decoder): Sequential(
#       (0): Linear(in_features=4, out_features=16, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=16, out_features=32, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# Epochs:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [1/1000], Average Loss: 0.0232
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [2/1000], Average Loss: 0.0230
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [3/1000], Average Loss: 0.0229
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [4/1000], Average Loss: 0.0228
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [5/1000], Average Loss: 0.0225
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [6/1000], Average Loss: 0.0224
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [7/1000], Average Loss: 0.0223
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [8/1000], Average Loss: 0.0220
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [9/1000], Average Loss: 0.0220
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [10/1000], Average Loss: 0.0218
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [11/1000], Average Loss: 0.0217
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [12/1000], Average Loss: 0.0216
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [13/1000], Average Loss: 0.0216
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [14/1000], Average Loss: 0.0216
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [15/1000], Average Loss: 0.0214
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [16/1000], Average Loss: 0.0213
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [17/1000], Average Loss: 0.0213
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [18/1000], Average Loss: 0.0212
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [19/1000], Average Loss: 0.0211
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [20/1000], Average Loss: 0.0210
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [21/1000], Average Loss: 0.0210
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [22/1000], Average Loss: 0.0209
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [23/1000], Average Loss: 0.0210
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [24/1000], Average Loss: 0.0209
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [25/1000], Average Loss: 0.0209
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [26/1000], Average Loss: 0.0208
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [27/1000], Average Loss: 0.0208
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [28/1000], Average Loss: 0.0208
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [29/1000], Average Loss: 0.0208
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [30/1000], Average Loss: 0.0207
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [31/1000], Average Loss: 0.0207
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [32/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [33/1000], Average Loss: 0.0207
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [34/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [35/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [36/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [37/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [38/1000], Average Loss: 0.0205
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [39/1000], Average Loss: 0.0206
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch
1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [502/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [503/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [504/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [505/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [506/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [507/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [508/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [509/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [510/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [511/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [512/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [513/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [514/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [515/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [516/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [517/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [518/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [519/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [520/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [521/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# ...
# ----
# Epoch [825/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [826/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [827/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [828/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [829/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [830/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [831/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [832/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [833/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [834/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [835/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [836/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [837/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [838/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [839/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [840/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [841/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [842/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [843/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [844/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [845/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [846/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [847/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [848/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [849/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [850/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [851/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [852/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [853/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [854/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [855/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [856/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [857/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [858/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [859/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [860/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [861/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [862/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [863/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [864/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [865/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [866/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [867/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [868/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [869/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [870/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [871/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [872/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [873/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [874/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [875/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [876/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [877/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [878/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [879/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [880/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [881/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [882/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [883/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [884/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [885/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [886/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [887/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [888/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [889/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [890/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [891/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [892/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [893/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [894/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [895/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [896/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [897/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [898/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [899/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [900/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [901/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [902/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [903/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [904/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [905/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [906/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [907/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [908/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [909/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [910/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [911/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [912/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [913/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [914/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [915/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [916/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [917/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [918/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [919/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [920/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [921/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [922/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [923/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [924/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [925/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [926/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [927/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [928/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [929/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [930/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [931/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [932/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [933/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [934/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [935/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [936/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [937/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [938/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [939/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [940/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [941/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [942/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [943/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [944/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [945/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [946/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [947/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [948/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [949/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [950/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [951/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [952/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [953/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [954/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [955/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [956/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [957/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [958/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [959/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [960/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [961/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [962/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [963/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [964/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [965/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [966/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [967/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [968/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [969/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [970/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [971/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [972/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [973/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [974/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [975/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [976/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [977/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [978/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [979/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [980/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [981/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [982/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [983/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [984/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [985/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [986/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [987/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [988/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [989/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [990/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [991/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [992/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [993/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [994/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [995/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [996/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [997/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [998/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [999/1000], Average Loss: 0.0000
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ----
# Epoch [1000/1000], Average Loss: 0.0000

# %% [markdown]
# ## d. Evaluation on Reconstruction

# %%
#############
### Problem 4(a): Evaluation on reconstruction
with torch.no_grad():
  output = point_vae(torus_pc_dataset.points.to(device))
  decoded_pc = output['imgs'].cpu().numpy()

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
plot_torus_point_cloud(decoded_pc[:, 0], decoded_pc[:, 1], decoded_pc[:, 2], ax, name="Decoded Data")
#############
# Out:
# <Axes3D: title={'center': 'Decoded Data'}, xlabel='X', ylabel='Y', zlabel='Z'>

# %% [markdown]
# ## e. Evaluation on Interpolation

# %%
#############
### Problem 4(v): Evaluation on linear interpolation
z0 = point_vae(torch.tensor([[0.0, 1.0, 0.]]).to(device))['z']
z1 = point_vae(torch.tensor([[0.0, -1.0, 0.]]).to(device))['z']

print(hidden_dims[-1])
num_steps = 100

weights = torch.linspace(0, 1, num_steps).view(-1, 1).to(device)
latent_vecs = weights * z0 + (1 - weights) * z1

with torch.no_grad():
    outputs = point_vae.vae.decode(torch.tensor(latent_vecs).to(device))

lin_traj = outputs.cpu().numpy()

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
plot_torus_point_cloud(lin_traj[:, 0], lin_traj[:, 1], lin_traj[:, 2], ax, color='r', name="Decoded Data")
plot_torus_point_cloud(decoded_pc[:, 0], decoded_pc[:, 1], decoded_pc[:, 2], ax, name="Decoded Data")
plt.show()
#############
# Out:
# 8
# C:\Windows\Temp\ipykernel_2864\470380799.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = point_vae.vae.decode(torch.tensor(latent_vecs).to(device))
